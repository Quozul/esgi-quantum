# %%
# Énigme à résoudre : https://www.youtube.com/watch?v=o6AAt2Yqu1k&pp=ygUXbGVzIMOpbmlnbWVzIHF1YW50aXF1ZXM%3D

from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister

# %%
q = QuantumRegister(3)
c = ClassicalRegister(1)
circuit = QuantumCircuit(q, c)

circuit.h(0)
circuit.h(2)
circuit.cx(0, 1)
# ---
circuit.cx(2, 1)
circuit.x(2)  # Je sais pas quelle porte mettre ici
circuit.cx(2, 0)
circuit.x(2)
# ---
circuit.swap(0, 1)
circuit.x(0)
circuit.x(1)
circuit.cx(2, 1)
circuit.x(2)
circuit.cx(2, 0)
circuit.x(2)

circuit.measure(0, 0)
circuit.measure(1, 0)
circuit.measure(2, 0)

circuit.draw('mpl')
